# %%
from __future__ import print_function

import argparse
import torch
import pickle 
import numpy as np 
import os 
import math 
import random 
import sys
import matplotlib.pyplot as plt 
import seaborn as sns
import scipy.io

import data 

from sklearn.decomposition import PCA
from torch import nn, optim
from torch.nn import functional as F

from detm import DETM
from utils import nearest_neighbors, get_topic_coherence

import pandas as pd
# Out:
# device: cuda:3
# device: cuda:3

# %%
from sklearn import cluster
from sklearn import metrics

# %%
device = torch.device("cuda:3" if torch.cuda.is_available() else "cpu")

# %%
root_dir = '/home/yiyi/nlp_tm/'

# %%
def load_data(input_dir= os.path.join(root_dir, 'preprocessed_data')):
    token_file = os.path.join(input_dir, 'bow_tokens')
    count_file = os.path.join(input_dir, 'bow_counts')
    time_file = os.path.join(input_dir, 'bow_timestamps')
    tokens = scipy.io.loadmat(token_file)['tokens'].squeeze()
    counts = scipy.io.loadmat(count_file)['counts'].squeeze()
    times = scipy.io.loadmat(time_file)['timestamps'].squeeze()
    
    return tokens, counts, times

# %%
tokens, counts, times = load_data()

# %%
def _eta_helper(rnn_inp):
    inp = model.q_eta_map(rnn_inp).unsqueeze(1)
    hidden = model.init_hidden()
    output, _ = model.q_eta(inp, hidden)
    output = output.squeeze()
    etas = torch.zeros(model.num_times, model.num_topics).to(device)
    inp_0 = torch.cat([output[0], torch.zeros(model.num_topics,).to(device)], dim=0)
    etas[0] = model.mu_q_eta(inp_0)
    for t in range(1, model.num_times):
        inp_t = torch.cat([output[t], etas[t-1]], dim=0)
        etas[t] = model.mu_q_eta(inp_t)
    return etas

# %%
filepath = 'results/detm_twitter_K_50_Htheta_800_Optim_adam_Clip_0.0_ThetaAct_relu_Lr_0.005_Bsz_1000_RhoSize_300_L_3_minDF_10_trainEmbeddings_1_val_ppl_2638.9_epoch_20'

# %%
model_path = os.path.join('/home/yiyi/nlp_tm/', filepath)

# %%
with open(model_path, 'rb') as f:
    model = torch.load(f)

# %%
model.to(device)
# Out:
# DETM(
#   (t_drop): Dropout(p=0.0, inplace=False)
#   (theta_act): ReLU()
#   (rho): Linear(in_features=300, out_features=20865, bias=False)
#   (q_theta): Sequential(
#     (0): Linear(in_features=20915, out_features=800, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=800, out_features=800, bias=True)
#     (3): ReLU()
#   )
#   (mu_q_theta): Linear(in_features=800, out_features=50, bias=True)
#   (logsigma_q_theta): Linear(in_features=800, out_features=50, bias=True)
#   (q_eta_map): Linear(in_features=20865, out_features=200, bias=True)
#   (q_eta): LSTM(200, 200, num_layers=3)
#   (mu_q_eta): Linear(in_features=250, out_features=50, bias=True)
#   (logsigma_q_eta): Linear(in_features=250, out_features=50, bias=True)
# )

# %%
with open(os.path.join('/home/yiyi/nlp_tm/preprocessed_data', 'vocab.pkl'), 'rb') as f:
        vocab = pickle.load(f)

# %%
vocab_size = len(vocab)

# %%
len(tokens)
# Out:
# 360097

# %%
indices = torch.split(torch.tensor(range(len(tokens))), 1000)

# %%
# get the centroid of words
keywords=  [ 'immigrant', 'immigrants',  'refugee', 'refugees','asylum',
      'migrant', 'migrants', 'internally displaced', 'UNHCR', 'asylee',
      'asylees', 'Asylee',  'resettled', 'resettlements',
      'immigration', 'Ateh', 're settlement', 'resettle', 'resettles', 'statelessness', 'Hagadera' , 'Domiz',
      'émigré', 'exile', 'displaced person', 'deserter', 'pariah', 'pariahs' ]
# keywords = ['immigrant', 'refugee']
keywords = list(set([k.lower() for k in keywords]))

keywords_selected = []
for k in keywords: 
    if k in vocab:
        keywords_selected.append(k)

# %%
keywords_selected
# Out:
# ['statelessness',
#  'asylum',
#  'pariah',
#  'deserter',
#  'immigrant',
#  'pariahs',
#  'asylee',
#  'immigration',
#  'refugee',
#  'unhcr',
#  'refugees',
#  'migrant',
#  'resettled',
#  'exile',
#  'immigrants',
#  'migrants',
#  'resettle']

# %%
def get_centroid_vector(embeddings, keywords):
    # vectors of whole embeddings.
    indexes_keywords = [vocab.index(word) for word in keywords]
    queries = [embeddings[index] for index in indexes_keywords] # vectors of the keywords
    kmeans = cluster.KMeans(n_clusters=1, random_state=0).fit(queries)
    centroid = kmeans.cluster_centers_[0]
    print('centroid size: ', centroid.shape)
    return centroid

# %%
from numpy import dot
from numpy.linalg import norm
def cosine_similarity(list_1, list_2):
    cos_sim = dot(list_1, list_2) / (norm(list_1) * norm(list_2))
    return cos_sim

# %%
def nearest_neighbors(word, vectors, vocab, num_words):
    index = vocab.index(word)
    query = embeddings[index]
    ranks = vectors.dot(query).squeeze()
    denom = query.T.dot(query).squeeze()
    denom = denom * np.sum(vectors**2, 1)
    denom = np.sqrt(denom)
    ranks = ranks / denom
    print(np.sort(ranks)[::-1][:num_words])
    mostSimilar = []
    [mostSimilar.append(idx) for idx in ranks.argsort()[::-1]]
    nearest_neighbors = mostSimilar[:num_words]
    nearest_neighbors = [vocab[comp] for comp in nearest_neighbors]
    print(nearest_neighbors)
    return nearest_neighbors

# %%
model.eval()
with torch.no_grad():
    # rnn_inp = data.get_rnn_input(tokens, counts, times, 8, vocab_size, len(tokens)).to(device)
    # etas = _eta_helper(rnn_inp).to(device)
    embeddings = model.rho.weight
    embeddings= embeddings.cpu().numpy()

# %%
indexes_keywords = [vocab.index(word) for word in keywords_selected]
queries = [embeddings[index] for index in indexes_keywords] #

# %%
kmeans = cluster.KMeans(n_clusters=1, random_state=0).fit(queries)
centroid = kmeans.cluster_centers_[0]

# %%
ranks= embeddings.dot(centroid).squeeze()
denom = centroid.T.dot(centroid).squeeze()
denom = denom*np.sum(embeddings*2, 1)
ranks = ranks/denom
mostSimilar = []
[mostSimilar.append(idx) for idx in ranks.argsort()[::-1]]
nearest_neighbors = mostSimilar[:20]
nearest_neighbors = [vocab[comp] for comp in nearest_neighbors]
nearest_neighbors
# Out:
# ['roberts',
#  'torycorruption',
#  'starry',
#  'nbd',
#  'vacant',
#  'mummy',
#  'ecuadorian',
#  'board',
#  'girona',
#  'advanced',
#  'rights',
#  'corporate',
#  'engerland',
#  'scott',
#  'congresswoman',
#  'varenna',
#  'christmaslight',
#  'teatro',
#  'hurts',
#  'kafala']

# %%
neigh_indices = [vocab.index(word) for word in nearest_neighbors]
neigh_q = [embeddings[index] for index in neigh_indices]

# %%
len(queries), len(neigh_q)
# Out:
# (17, 20)

# %%
len(keywords_selected)
# Out:
# 17

# %%
queries.append(centroid)

# %%
n = queries+neigh_q
n_arr = np.array(n)

# %%
n_arr.shape
# Out:
# (38, 300)

# %%
ks =keywords_selected+['centroid']+nearest_neighbors

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0, n_iter=10000, perplexity=7)
T = tsne.fit_transform(n_arr)

# %%
colors = ['blue' for x in range(0,17)]+['red']+['orange' for x in range(0,20) ]

# %%
len(colors)
# Out:
# 38

# %%
plt.figure(figsize=(40,10))
plt.scatter(T[:, 0], T[:, 1], s=40, c=colors)

for label, x, y in zip(ks, T[:, 0], T[:, 1]):
    plt.annotate(label, xy=(x+2, y+2), xytext=(0, 0), textcoords='offset points', fontsize=20)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig('images/dist_emb_detm_k-50.png')

# %%
confidences =[]
model.eval()
with torch.no_grad():
    rnn_inp = data.get_rnn_input(tokens, counts, times, 8, vocab_size, len(tokens)).to(device)
    etas = _eta_helper(rnn_inp).to(device)
#     embeddings = model.rho.weight
#     embeddings= embeddings.cpu().numpy()
#     indexes_keywords = [vocab.index(word) for word in keywords]
#     queries = [embeddings[index] for index in indexes_keywords] # vectors of the keywords
#     print(cosine_similarity(queries[0], queries[1]))
#     centroid = get_centroid_vector(embeddings, keywords_selected)

    for idx, ind in enumerate(indices):
        data_batch, times_batch = data.get_batch(
                        tokens, counts, ind, len(vocab),300, temporal=True, times=times)
        sums = data_batch.sum(1).unsqueeze(1)
        normalized_data_batch = data_batch / sums
        eta_td = etas[times_batch.type('torch.LongTensor')].to(device)
        inp = torch.cat([eta_td, normalized_data_batch], dim=1).to(device)
        q_theta = model.q_theta(inp) # 1000, 800
        lr = nn.Linear(q_theta.shape[1], 300).to(device)
        mu_theta = lr(q_theta).cpu().numpy()
        for i in mu_theta:
            cos = cosine_similarity(i, centroid)
            confidences.append(cos)

        # mu_theta = model.mu_q_theta(q_theta) # 1000, 75
        print(q_theta.shape)
        print(mu_theta.shape)
# Out:
# /home/yiyi/nlp_tm/models/DETM/data.py:117: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /opt/conda/conda-bld/pytorch_1607370117127/work/torch/csrc/utils/python_arg_parser.cpp:882.)
#   tmp = (times_batch == t).nonzero()
# idx: 0/361
# idx: 20/361
# idx: 40/361
# idx: 60/361
# idx: 80/361
# idx: 100/361
# idx: 120/361
# idx: 140/361
# idx: 160/361
# idx: 180/361
# idx: 200/361
# idx: 220/361
# idx: 240/361
# idx: 260/361
# idx: 280/361
# idx: 300/361
# idx: 320/361
# idx: 340/361
# idx: 360/361
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([1000, 800])
# (1000, 300)
# torch.Size([97, 800])
# (97, 300)

# %%
len([x for x in confidences if x>0])
# Out:
# 176557

# %%
len([x for x in confidences if x>0])
# Out:
# 176778

# %%
df = pd.read_csv(os.path.join(root_dir, 'datasets/df_detm_topics_k50.csv'), index_col=0)

# %%
df.head()
# Out:
#                                                               text_id  \
# id
# 285908615561363456  [13807, 12242, 16517, 4854, 16885, 13840, 7284...
# 285909630868152320            [11403, 16517, 13618, 1431, 1404, 1881]
# 285915248383361026                                 [638, 2601, 20286]
# 285921849446117376                                      [17018, 9987]
# 285922536942866432                               [2721, 16517, 12121]
#
#                     year_id country_code                id.1  \
# id
# 285908615561363456        0           GB  285908615561363456
# 285909630868152320        0           DE  285909630868152320
# 285915248383361026        0           GB  285915248383361026
# 285921849446117376        0           GB  285921849446117376
# 285922536942866432        0           GB  285922536942866432
#
#                                                                  text  \
# id
# 285908615561363456  Completely missed the New Year beginning, too ...
# 285909630868152320  happy new year all of you who lives in #europe...
# 285915248383361026             Damien Sandow is awesome #YoureWelcome
# 285921849446117376  Ryan was looking at me like I needed to be in ...
# 285922536942866432  #welcome #to #2013 #i #hope #this #year #is #b...
#
#                                   created_at  \
# id
# 285908615561363456  2013-01-01T00:41:40.000Z
# 285909630868152320  2013-01-01T00:45:42.000Z
# 285915248383361026  2013-01-01T01:08:01.000Z
# 285921849446117376  2013-01-01T01:34:15.000Z
# 285922536942866432  2013-01-01T01:36:59.000Z
#
#                                                                   geo  \
# id
# 285908615561363456  {'coordinates': {'type': 'Point', 'coordinates...
# 285909630868152320  {'coordinates': {'type': 'Point', 'coordinates...
# 285915248383361026  {'coordinates': {'type': 'Point', 'coordinates...
# 285921849446117376  {'place_id': 'a3f4491c1a3bfe66', 'coordinates'...
# 285922536942866432  {'coordinates': {'type': 'Point', 'coordinates...
#
#                     author_id  \
# id
# 285908615561363456  174028844
# 285909630868152320  615040794
# 285915248383361026   73127632
# 285921849446117376  398595226
# 285922536942866432  191530036
#
#                                                              entities  year  \
# id
# 285908615561363456  {'hashtags': [{'start': 59, 'end': 80, 'tag': ...  2013
# 285909630868152320  {'hashtags': [{'start': 39, 'end': 46, 'tag': ...  2013
# 285915248383361026  {'annotations': [{'start': 0, 'end': 12, 'prob...  2013
# 285921849446117376  {'annotations': [{'start': 0, 'end': 3, 'proba...  2013
# 285922536942866432  {'hashtags': [{'start': 0, 'end': 8, 'tag': 'w...  2013
#
#                     month  day  \
# id
# 285908615561363456      1    1
# 285909630868152320      1    1
# 285915248383361026      1    1
# 285921849446117376      1    1
# 285922536942866432      1    1
#
#                                                     preprocessed_text  topic
# id
# 285908615561363456  completely miss new year beginning engross car...      6
# 285909630868152320       happy new year live europe party start right      6
# 285915248383361026                 damien sandow awesome yourewelcome      6
# 285921849446117376       ryan look like need asylum troublemaker come      6
# 285922536942866432            welcome hope year well litte world know      6

# %%
len(df)
# Out:
# 360097

# %%
df['cossim']= confidences

# %%
df[df['cossim']>=0.01]
# Out:
#                                                                text_id  \
# id
# 285908615561363456   [13807, 12242, 16517, 4854, 16885, 13840, 7284...
# 285909630868152320             [11403, 16517, 13618, 1431, 1404, 1881]
# 285915248383361026                                  [638, 2601, 20286]
# 285921849446117376                                       [17018, 9987]
# 285922536942866432                                [2721, 16517, 12121]
# ...                                                                ...
# 1344791154005573632  [1431, 10434, 1206, 6258, 13960, 2093, 8090, 9...
# 1344792331766083584             [10314, 4018, 20597, 7278, 10915, 985]
# 1344793429360959491                         [17683, 14049, 1833, 1457]
# 1344793756189544450                                      [1457, 14898]
# 1344795058332184577  [11403, 16517, 4682, 12530, 6536, 5885, 12658,...
#
#                      year_id country_code                 id.1  \
# id
# 285908615561363456         0           GB   285908615561363456
# 285909630868152320         0           DE   285909630868152320
# 285915248383361026         0           GB   285915248383361026
# 285921849446117376         0           GB   285921849446117376
# 285922536942866432         0           GB   285922536942866432
# ...                      ...          ...                  ...
# 1344791154005573632        7           GB  1344791154005573632
# 1344792331766083584        7           IT  1344792331766083584
# 1344793429360959491        7           GB  1344793429360959491
# 1344793756189544450        7           GB  1344793756189544450
# 1344795058332184577        7           GB  1344795058332184577
#
#                                                                   text  \
# id
# 285908615561363456   Completely missed the New Year beginning, too ...
# 285909630868152320   happy new year all of you who lives in #europe...
# 285915248383361026              Damien Sandow is awesome #YoureWelcome
# 285921849446117376   Ryan was looking at me like I needed to be in ...
# 285922536942866432   #welcome #to #2013 #i #hope #this #year #is #b...
# ...                                                                ...
# 1344791154005573632  As #Europe is one hour ahead of #Britain they ...
# 1344792331766083584  #LeaveALightOnForScotland, because #Scotland w...
# 1344793429360959491  Pass it on #IndyScotland21 #ScotlandinEU #Scot...
# 1344793756189544450  Here’s to a better 2021! #ScotlandInEurope #Sc...
# 1344795058332184577  Happy New Year @TobyWhithouse @marcuswhitney1 ...
#
#                                    created_at  \
# id
# 285908615561363456   2013-01-01T00:41:40.000Z
# 285909630868152320   2013-01-01T00:45:42.000Z
# 285915248383361026   2013-01-01T01:08:01.000Z
# 285921849446117376   2013-01-01T01:34:15.000Z
# 285922536942866432   2013-01-01T01:36:59.000Z
# ...                                       ...
# 1344791154005573632  2020-12-31T23:42:50.000Z
# 1344792331766083584  2020-12-31T23:47:31.000Z
# 1344793429360959491  2020-12-31T23:51:53.000Z
# 1344793756189544450  2020-12-31T23:53:11.000Z
# 1344795058332184577  2020-12-31T23:58:21.000Z
#
#                                                                    geo  \
# id
# 285908615561363456   {'coordinates': {'type': 'Point', 'coordinates...
# 285909630868152320   {'coordinates': {'type': 'Point', 'coordinates...
# 285915248383361026   {'coordinates': {'type': 'Point', 'coordinates...
# 285921849446117376   {'place_id': 'a3f4491c1a3bfe66', 'coordinates'...
# 285922536942866432   {'coordinates': {'type': 'Point', 'coordinates...
# ...                                                                ...
# 1344791154005573632  {'place_id': '609de05ff9db5cfe', 'place': {'fu...
# 1344792331766083584  {'place_id': '0f14a0bc5fea038d', 'place': {'fu...
# 1344793429360959491  {'place_id': '73cc26d418860ddd', 'place': {'fu...
# 1344793756189544450  {'place_id': '0af014accd6f6e99', 'place': {'fu...
# 1344795058332184577  {'place_id': '0097eb6734bf322d', 'place': {'fu...
#
#                       author_id  \
# id
# 285908615561363456    174028844
# 285909630868152320    615040794
# 285915248383361026     73127632
# 285921849446117376    398595226
# 285922536942866432    191530036
# ...                         ...
# 1344791154005573632   108713501
# 1344792331766083584   492589316
# 1344793429360959491   151383933
# 1344793756189544450  1492027154
# 1344795058332184577    77997068
#
#                                                               entities  year  \
# id
# 285908615561363456   {'hashtags': [{'start': 59, 'end': 80, 'tag': ...  2013
# 285909630868152320   {'hashtags': [{'start': 39, 'end': 46, 'tag': ...  2013
# 285915248383361026   {'annotations': [{'start': 0, 'end': 12, 'prob...  2013
# 285921849446117376   {'annotations': [{'start': 0, 'end': 3, 'proba...  2013
# 285922536942866432   {'hashtags': [{'start': 0, 'end': 8, 'tag': 'w...  2013
# ...                                                                ...   ...
# 1344791154005573632  {'hashtags': [{'start': 3, 'end': 10, 'tag': '...  2020
# 1344792331766083584  {'hashtags': [{'start': 0, 'end': 25, 'tag': '...  2020
# 1344793429360959491  {'hashtags': [{'start': 11, 'end': 26, 'tag': ...  2020
# 1344793756189544450  {'hashtags': [{'start': 25, 'end': 42, 'tag': ...  2020
# 1344795058332184577  {'mentions': [{'start': 15, 'end': 29, 'userna...  2020
#
#                      month  day  \
# id
# 285908615561363456       1    1
# 285909630868152320       1    1
# 285915248383361026       1    1
# 285921849446117376       1    1
# 285922536942866432       1    1
# ...                    ...  ...
# 1344791154005573632     12   31
# 1344792331766083584     12   31
# 1344793429360959491     12   31
# 1344793756189544450     12   31
# 1344795058332184577     12   31
#
#                                                      preprocessed_text  topic  \
# id
# 285908615561363456   completely miss new year beginning engross car...      6
# 285909630868152320        happy new year live europe party start right      6
# 285915248383361026                  damien sandow awesome yourewelcome      6
# 285921849446117376        ryan look like need asylum troublemaker come      6
# 285922536942866432             welcome hope year well litte world know      6
# ...                                                                ...    ...
# 1344791154005573632  europe hour ahead britain celebrate newyear bl...     47
# 1344792331766083584  leavealightonforscotland scotland soon europea...     10
# 1344793429360959491  pass indyscotland scotlandineu scotlandineurop...     10
# 1344793756189544450  here well scotlandineurope scottishindependenc...     10
# 1344795058332184577  happy new year thank entertaining hard work be...     10
#
#                        cossim
# id
# 285908615561363456   0.039144
# 285909630868152320   0.038019
# 285915248383361026   0.047056
# 285921849446117376   0.068725
# 285922536942866432   0.038114
# ...                       ...
# 1344791154005573632  0.057520
# 1344792331766083584  0.057520
# 1344793429360959491  0.057520
# 1344793756189544450  0.057520
# 1344795058332184577  0.057520
#
# [148544 rows x 15 columns]

# %%
df.to_csv(os.path.join(root_dir, 'datasets/df_detm_topics_k50_confidence.csv'))

# %%
threshold = 0

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
df['text'].groupby(pd.cut(df['cossim'], 20)).count().plot(kind='bar')

# %%
len(df['topic'].value_counts())
# Out:
# 32

# %%
df['topic'].value_counts()
# Out:
# 9     89811
# 20    53644
# 10    53082
# 46    39324
# 47    34722
# 6     28837
# 4     23444
# 7     17366
# 22    16272
# 31     1558
# 41      888
# 34      457
# 8       189
# 15      144
# 19      113
# 30       49
# 38       46
# 37       43
# 2        31
# 36       27
# 3        10
# 5        10
# 33        8
# 43        5
# 49        4
# 23        3
# 1         3
# 11        2
# 18        2
# 48        1
# 24        1
# 29        1
# Name: topic, dtype: int64

# %%
samples = df[df['cossim']>=0.01]

# %%
len(samples)
# Out:
# 151256

# %%
samples['topic'].value_counts()
# Out:
# 69    37890
# 55    34818
# 37    18984
# 51    18322
# 48    13894
# 17     9562
# 7      8303
# 22     6597
# 72      808
# 0       797
# 3       318
# 56      150
# 21      148
# 46      146
# 19       76
# 54       62
# 67       62
# 64       59
# 58       46
# 61       29
# 36       27
# 63       22
# 62       22
# 35       20
# 32       16
# 14       16
# 59       13
# 15       11
# 74       10
# 53       10
# 8         7
# 13        4
# 71        4
# 47        2
# 9         1
# Name: topic, dtype: int64

# %%
samples[samples['topic']==13]
# Out:
#                                                             text_id  year_id  \
# id
# 739795555598098432                    [6487, 691, 11443, 6487, 691]        3
# 781148016094748672               [6959, 9754, 1431, 691, 6959, 691]        3
# 807615988631900160                     [1431, 691, 6487, 6487, 691]        3
# 813903053908647936  [691, 691, 13819, 12634, 10369, 181, 691, 5532]        3
#
#                    country_code                id.1  \
# id
# 739795555598098432           ES  739795555598098432
# 781148016094748672           ES  781148016094748672
# 807615988631900160           ES  807615988631900160
# 813903053908647936           ES  813903053908647936
#
#                                                                  text  \
# id
# 739795555598098432  #madrid #spain #palaciodecibeles #refugeeswelc...
# 781148016094748672  🏝🏝🏝 #alicante #beach #europe #spain @ Alicante...
# 807615988631900160  #europe #spain🇪🇸 #madrid🇪🇸 @ Madrid, Spain htt...
# 813903053908647936  Spain |  Spain won't be taking in Muna, the mi...
#
#                                   created_at  \
# id
# 739795555598098432  2016-06-06T12:26:19.000Z
# 781148016094748672  2016-09-28T15:06:14.000Z
# 807615988631900160  2016-12-10T16:00:31.000Z
# 813903053908647936  2016-12-28T00:23:04.000Z
#
#                                                                   geo  \
# id
# 739795555598098432  {'coordinates': {'type': 'Point', 'coordinates...
# 781148016094748672  {'place_id': '2e858e47881ddc48', 'coordinates'...
# 807615988631900160  {'coordinates': {'type': 'Point', 'coordinates...
# 813903053908647936  {'place_id': '206c436ce43a43a3', 'coordinates'...
#
#                     author_id  \
# id
# 739795555598098432   15330946
# 781148016094748672  159639553
# 807615988631900160   31822685
# 813903053908647936  186478529
#
#                                                              entities  year  \
# id
# 739795555598098432  {'urls': [{'start': 66, 'end': 89, 'url': 'htt...  2016
# 781148016094748672  {'annotations': [{'start': 41, 'end': 55, 'pro...  2016
# 807615988631900160  {'annotations': [{'start': 33, 'end': 45, 'pro...  2016
# 813903053908647936  {'urls': [{'start': 115, 'end': 138, 'url': 'h...  2016
#
#                     month  day  \
# id
# 739795555598098432      6    6
# 781148016094748672      9   28
# 807615988631900160     12   10
# 813903053908647936     12   28
#
#                                                     preprocessed_text  topic  \
# id
# 739795555598098432  madrid spain palaciodecibele refugeeswelcome m...     13
# 781148016094748672         alicante beach europe spain alicante spain     13
# 807615988631900160                   europe spain madrid madrid spain     13
# 813903053908647936  spain spain wo take muna migrant child bear fr...     13
#
#                       cossim
# id
# 739795555598098432  0.017466
# 781148016094748672  0.055720
# 807615988631900160  0.118667
# 813903053908647936  0.115506

# %%
samples = df[df['cossim']>=0.01].sample(30)

# %%
list(zip(samples.text, samples.cossim, samples.topic))
# Out:
# [("#MusketeersEurope Last one of my screenshots of #TheMusketeers S3 #Set with a lot action showing how perfect #Cast and #Crew worked. It's one of the triumphant ⚜️ final scenes S3ep6 Death Of A Hero #Treville #HugoSpeer #Porthos #HowardCharles #Athos #TomBurke #ThrowbackThursay https://t.co/Yhxpuo6SJt",
#   0.023792373160939198,
#   69),
#  ('“@TheMoeDee: Today around exactly half of the population of syria is refugees. Either internally or externally.”',
#   0.06641904848980816,
#   37),
#  ('The @EU_Commission follows closely the epidemiological situation in the Sahrawi refugee camps &amp; has well-functioning communication channels with the #Sahrawi_Red_Crescent responsible for aid delivery in the camps and with all relevant UNAs, including #MINURSO #freewesternsahara https://t.co/gaZ7rMBGtM',
#   0.07898203566995537,
#   55),
#  ("@WebsterFrank @Fox_Claire @ajayjagota @brexitparty_uk Where was the racism? I didn't vote Brexit because I'm a racist. I think you are equating control of immigration with racism. The Brexit Party wants controlled immigration and let in the best people we need from wherever, whatever their race, colour or creed. Its that simple.",
#   0.02234664182718638,
#   69),
#  ('MILAN: The internationally accepted arbiter of taste in fashion and design. #Milan #Italy #Europe #Travel http://t.co/RS48TNXT7V',
#   0.037455336663627756,
#   51),
#  ('Hammond still promoting myth that search and rescue encourages other refugees to make perilous Med Crossing typical cruel callous Tory',
#   0.06389583827026872,
#   51),
#  ("@Aswed_F Syrians fighters are real soldiers. With real harsh daylife. And fighting in #Syria land isn't a TV reality show.",
#   0.03677548755251517,
#   69),
#  ('Time for #RhodesScholars :) #yourewelcome', 0.09730053484569416, 17),
#  ('@fraser_riddell The note for the CD says the superintendent of the asylum believed that music played a part in rehabilitation. Danced too!',
#   0.012084572090908324,
#   51),
#  ('#Modern #Slavery #HumanTrafficking #Forced #Marriage #Conference 31 March 2020. Book https://t.co/WzFTFYhF9l @DavidFordxMLA @andygeorgeni @sharonh2h @MarriottAngie @cllr_petermcrey @ChiefConPSNI @alfiecbwong @belfastcc @EileenChanHu @nisha_tandon @Justice_NI',
#   0.037871722037019315,
#   55),
#  ('And voted........ #ukrain #europeanunion #referendum @ Bs. De Boog https://t.co/Q0anx8CMYJ',
#   0.06889258086591066,
#   48),
#  ('Firefighter and father-of-two deployed to Bangladesh to with assist medical efforts following deadly diphtheria outbreak at refugee camps https://t.co/tNwSqEtDw8 #Surrey https://t.co/rn8XRaNuSF',
#   0.08057216798626855,
#   7),
#  ('Polish labourer takes over the canteen with his clothes washes and shaves in the sink and now putting posters up supporting immigrants PRICK',
#   0.02995378096890679,
#   37),
#  ('Space Warp.Used #circularapp 🔲🔲🔲🔲🔲🔲🔲🔲🔲🔲🔲🔲🔲🔲 #aliens42  #cryptic_aesthetic #masters_of_darkness… https://t.co/4RiQqtVcCY',
#   0.03611265702092089,
#   51),
#  ("@benandjerrysUK @pritipatel Hey cutie, completely love that you're supporting refugees and calling out Tories.Love the human rights vibe babes, looks gorgeous on you.Just wondering, isn't this you? Would love to know if you'll be serving human rights vibes and supporting Palestinians. https://t.co/lZOYKVf3Tm",
#   0.03886871054405495,
#   55),
#  ('David Cameron needs to learn that UKIP-style measures against immigration will only increase anti-immigrant sentiment NOT UK prosperity.',
#   0.04677704547834275,
#   51),
#  ('Left the lake district in sun and we hit the south west and it rains! #welcomehome',
#   0.1012944153564612,
#   37),
#  ('The conflict with Russia has forged a new sense of Ukrainian identity, much to Russian President Vladimir Putin’s chagrin. #Donbas #Crimea #Ukraine #Europe #Russia #war https://t.co/35n52tqpPN',
#   0.1396383538912956,
#   69),
#  ('Germany:  Afghan ‘asylum seeker’ confesses to raping an 11-year-old with special needs - Voice of Europe https://t.co/XZZC77buNR',
#   0.024036268023505888,
#   55),
#  ("The power of the English language to attract #calaismigrants can't be underestimated #migrants are evidence",
#   0.026746124469365848,
#   51),
#  ('Cold. #paris #france #europe #eurotrip #away @ Effel Tower Paris https://t.co/eXcODQMRI4',
#   0.055272108800353645,
#   48),
#  ('@barnetbugle absolutely. Great he has been converted to rational thought and now sees the benefit of immigration.',
#   0.06470696174289797,
#   17),
#  ('Our Best Selling Kit this month is the Flueboss colourcoded Extra Flexible Liner Powersweeping Kit PSKS01SB. Contact us sales@rodstation.co.uk or call us on 01446500695. #rodstation #madeintheuk #chimney #chimneysweeps #tools #powertools #nacs #wales #uk #europe #USA #Russia https://t.co/QDwQtI06m0',
#   0.06330053229184704,
#   69),
#  ('Forgot I did this ha ha ha. I made all of Year 11 set up school email at the beginning of the year... and it updates their calendar 😂#yourewelcome #missingmass https://t.co/fvGBjoxnHt',
#   0.02140535364698301,
#   69),
#  ('BBC News - Man jailed for smuggling Vietnamese migrants into Kenthttps://t.co/jljgkRofiGEgert Kajaci, 35,',
#   0.013839729865480302,
#   69),
#  ('Maybe we are not that many people but we try to be so loud as we can, for you guys! @tokiohotel #aliens #TokioHotelWeNeedYou ♥',
#   0.07767490222918813,
#   37),
#  ('This is the biggest reason most British People voted to leave the EU.  Looks like Italy will be the next wanting independence.  The EU have themselves to blame for Brexit. All these nations could unite to sort out illegal immigration https://t.co/oBfcHAMgUY',
#   0.012300005027003598,
#   55),
#  ('@POTUS  Douma: 7500 martyrs. Are you sure #Assad is just killing #Terrorist? #StandWithDouma #Syria https://t.co/MxIOpjTic1"',
#   0.06566063034515558,
#   48),
#  ('Ahh London!!!!! 🗺👣💂#unitedkingdom #london #londoneye #magic #freelife #believe #trust #europe… https://t.co/RjHNP0vaf4',
#   0.05958311710492069,
#   48),
#  ('Lake Como, you took my breath away..#LakeComo #LagoDiComo #Italy #Italiano #Italia #Europe… https://t.co/5w8PiEzfkU',
#   0.03311666352737227,
#   51)]
