# %%
import pandas as pd

# %%
df= pd.read_csv('k_10/df_detm_topics_k10_confidence.csv', index_col=0)

# %%
samples.

# %%
samples = df[df['cossim']>0]

# %%
samples[samples['topic']==8].year.value_counts()
# Out:
# 2015    1850
# 2017     268
# 2014      36
# 2016       2
# Name: year, dtype: int64

# %%
df[df['topic']==8].year.value_counts()
# Out:
# 2015    3145
# 2017     707
# 2014      52
# 2016       8
# Name: year, dtype: int64

# %%
df_covid_immig = df[df['preprocessed_text'].str.contains(r'covid')==True][df['preprocessed_text'].str.contains(r'immigrant')==True]
# Out:
# <ipython-input-23-de7c1170af1d>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_covid_immig = df[df['preprocessed_text'].str.contains(r'covid')==True][df['preprocessed_text'].str.contains(r'immigrant')==True]

# %%
df_covid_immig[df['preprocessed_text'].str.contains(r'border')==True]['text'].sample(10).tolist()
# Out:
# <ipython-input-26-9abd6b794e4d>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_covid_immig[df['preprocessed_text'].str.contains(r'border')==True]['text'].sample(10).tolist()
# ['We can’t control our borders now. The oil slick of immigrants will still cross the Channel with nothing to stop them. The UK Government lies about Covid 19 along with Priti Patel lying about the Immigrants! https://t.co/NOX6ykfST9',
#  'Totally agree this can’t continue. Seems like our borders are wide open atm. I wonder how many of these illdgal immigrants are carrying the Covid virus! https://t.co/0e6a4WIv5w',
#  '@igfield73 @thecoastguy A bit rich coming from a nation of racists who voted for Brexit in the belief that it would restore borders and prevent the influx of immigrants to the detriment of the economy - a considerable number of these immigrants are now treating your COVID ill in the NHS hospitals - 🤔',
# ...

# %%
df_covid_immig
# Out:
#                                                                text_id  \
# id
# 1235436769664847872  [18499, 14411, 7111, 2694, 14640, 16875, 18633...
# 1236255165449146369  [8582, 101, 4578, 1475, 4635, 4350, 5379, 308,...
# 1236790465913131008  [8201, 6566, 9481, 17025, 9481, 19165, 4424, 3...
# 1237403573513838592                    [2694, 10391, 9065, 1337, 6566]
# 1238897279798476800             [2592, 12518, 6566, 13276, 2694, 6115]
# ...                                                                ...
# 1344076683113091074  [9868, 1055, 17059, 6566, 20234, 1910, 8952, 2...
# 1344262572372078593  [15153, 20857, 4578, 892, 8657, 14121, 19430, ...
# 1344350348723572739        [10685, 6108, 9240, 2694, 14551, 6566, 535]
# 1344609589736697857  [16297, 5985, 8201, 6566, 8008, 13819, 16178, ...
# 1344616895400603650  [16178, 3580, 1792, 3031, 14705, 17836, 13618,...
#
#                      year_id country_code                 id.1  \
# id
# ...

# %%
df =df[df['cossim']>0]

# %%
df
# Out:
#                                                                text_id  \
# id
# 285908615561363456   [13807, 12242, 16517, 4854, 16885, 13840, 7284...
# 285909630868152320             [11403, 16517, 13618, 1431, 1404, 1881]
# 285915248383361026                                  [638, 2601, 20286]
# 285921849446117376                                       [17018, 9987]
# 285922536942866432                                [2721, 16517, 12121]
# ...                                                                ...
# 1344791154005573632  [1431, 10434, 1206, 6258, 13960, 2093, 8090, 9...
# 1344792331766083584             [10314, 4018, 20597, 7278, 10915, 985]
# 1344793429360959491                         [17683, 14049, 1833, 1457]
# 1344793756189544450                                      [1457, 14898]
# 1344795058332184577  [11403, 16517, 4682, 12530, 6536, 5885, 12658,...
#
#                      year_id country_code                 id.1  \
# id
# ...

# %%
df[df['topic']==9]
# Out:
#                                                                text_id  \
# id
# 504055107986931713                                      [18702, 18702]
# 504075316537860096                                      [18702, 18702]
# 505679392119721985                               [18702, 18702, 18702]
# 505679644583292928                                      [18702, 18702]
# 512324813378301952                   [12380, 595, 18702, 18702, 18702]
# ...                                                                ...
# 1330681491702108161  [6305, 1219, 13214, 10656, 7620, 1219, 13541, ...
# 1331745751190413313  [1532, 13038, 12501, 5411, 12093, 754, 5963, 7...
# 1332250800056377344  [12212, 12671, 17066, 16583, 14252, 13807, 474...
# 1338378233000103939  [19627, 15707, 1532, 7068, 13141, 3404, 13619,...
# 1339819627925352448  [16719, 1532, 19052, 5963, 10975, 8369, 6203, ...
#
#                      year_id country_code                 id.1  \
# id
# ...
